# %% [markdown]
# ---
# comments: true
# layout: post
# title: MCQ Collegeboard Corrections
# description: Questions and their correct answers from the 2021 Practice Exam.
# type: hacks
# courses: { csp: {week: 10} }
# ---

# %% [markdown]
# # ------------------------------------------------------------------------------------
# ## My Score:
#     I scored 46/54 or 85% for the ones that I were able to complete throughout the class time.
#
# ## My Journey:
#
#     My score improved this trimester from last tri's 81% to this tri's 85%.
#     Reasons for Improvement:
#         - Revisions of past problems from old Collegeboard MCQs
#         - More understanding of concepts such as Pseudo Code and Digital Divide
#
# ## Questions Needing Corrections:
#
# ### Question 7:
# ![Image](https://github.com/nighthawkcoders/teacher_portfolio/assets/75818107/7d722d0b-1c8d-4e2a-aae4-a8dccf5996ac)
#
# The correct answer is 4. 2 is incorrect because the counter increases by one each time before ending at the red space. The counter makes four moves, not two. Collegeboard: The counter is incremented once for each time the game piece moves. The game piece makes four moves before ending in the red space.
#
# ### Question 9:
# ![Image](https://github.com/nighthawkcoders/teacher_portfolio/assets/75818107/4e6a7bd9-1411-4512-b7c6-a25f3b85ad12)
#
# The correct answer is B. I got this question incorrect because I did not know what an analog audio signal is. I chose C as my answer; C is incorrect because audio data is not represented digitally, and at the lowest level all digital data is actually represented by sequences of bits.
#
# ### Question 14:
# ![Image](https://github.com/nighthawkcoders/teacher_portfolio/assets/75818107/582855c7-8a16-4f6b-bc55-638ab3f250a8)
#
# The correct answer is C; Lines 8 and 12 ahould be interchanged. I chose answer choice D; D is incorrect because D would create an infinite loop and in this case "count" would not update. However, by changing lines 8 and 12, the count will actually update because return will be false in line 8 before repeating.
#
# ### Question 16:
# ![Image](https://github.com/nighthawkcoders/teacher_portfolio/assets/75818107/f2b47ca0-4906-45c9-b3c9-883ba7db003f)
#
# The correct answer is B; Individuals can freely distribute or use the contents of the e-book without needing to obtain additional permissions from the author. I chose choice D; D is incorrect. I chose D because I believed it was the most accurate, and I did not know what a Creative Commons license is. However, now I know with a Creative Commons License the main consequcence is that individuals can use the e-book without needing permission. In fact, D is not typically a consequence.
#
# ### Question 23:
# ![Image](https://github.com/nighthawkcoders/teacher_portfolio/assets/75818107/7afd47cb-8c0e-466b-bb11-1945f1524e3e)
#
# The correct answer is B; The Internet is designed to scale to support an increasing number of users. I chose choice A. The Internet uses standardized, open communication protocols. I got this wrong because I thought proprietary meant open, but in fact nonproprietary means open. Also, the Internet is able to handle many users at a single time, that is why B is the correct option.
#
# ### Question 33:
# ![Image](https://github.com/nighthawkcoders/teacher_portfolio/assets/75818107/ced18a90-c400-464b-b176-2d99a390bf2c)
#
# The correct answer is B; Algorithm II attempts to use an algorithmic approach to solve an otherwise undecidable problem. I chose choice A. I did not chose B because I did not know what heuristic meant. Heuristic: proceeding to a solution by trial and error or by rules that are only loosely defined. When comparing algorithm II with I, algorithm II solves the problem through trial and error to approximate a solution.
#
# ### Question 44:
# ![Image](https://github.com/nighthawkcoders/teacher_portfolio/assets/75818107/517b94d1-b0bf-4015-b71b-d50b2d641037)
#
# The correct answer is B; The account balances are represented using a fixed number of bits, resulting in overflow errors. This is wrong because an overflow occurs when a value exceeds the maximum representable value. This error does not normally have an effect of imprecision of values. The correct answer is resulting in round-off errors. I am still confused about this one.
#
# ### Question 48:
# ![Image](https://github.com/nighthawkcoders/teacher_portfolio/assets/75818107/8b8518ae-c98e-4d98-9ffb-d9a6469a8b14)
#
# The correct answer is A; An unauthorized individual gains the ability to view network traffic by connecting to a network router that uses weak or no security measures. I chose answer C. Answer C is incorrect because answer choice C is actually an example of a phishing attack. This attack does obtain personal information, but it does not allo unauthorized individuals to intercept the information.
#
# ## Takeaways:
# After taking the 2021 Practice Exam, I realized I have to practice the abilities of time management and focus. Throughout the exam, I got distracted and had to reread each question two-three times through. I also realized because of this I was only able to complete 54 of the 70 total questions within the given time; with 85% accuracy.
#
# In these upcoming weeks, I strive to complete many practice tests and problems. I will also review concepts, code, through AP College Board videos and old team teaches from Trimester 1 and 2.
#
# ## Conclusion:
#  I am satisifed with my score because I have improved from last time I took this Collegeboard MCQ. I strive to do better next time, and implement the new knowledge into my test-taking skills. I will need to review some of these problems again, and concepts such as the legal/ethical factors of computing, and using an algorithm. I will also do more practice exams to strengthen my weaker focusing skills and time managment skills. This was overall a good benchmark exam for self-evaluation.
