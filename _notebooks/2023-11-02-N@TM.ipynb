# %% [markdown]
# ---
# toc: true
# comments: true
# layout: post
# title: Issues from N@TM
# description: After seeing other groups from other class periods display their creations for night at the museum, I helped grade three other groups.
# type: tangibles
# courses: { csp: {week: 10} }
# ---

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------
#
# Group: Akhil Singamneni, Advik Garg, Aashray Rajagopalan, and Srijan Atti
# - Period: CSP P5
#
# USAGE OF:
#
# - [X] Frontend
# - [X] Backend
# - [X] API
# - [] Agile
#
# HOOK:
# Points: 4.0
# Reason: Very engaging home page, with moving pictures and humor that intrigued me.
#
# KNOWLEDGE:
# Points: 3.9
# Reason: Well explained code, and was able to interact with the song finder at N@TM. Only thing not really talked about enough was the API, but showed data storage so that was good.
#
# VALUE:
# Points: 1.0
# Reason: Code works perfectly and is accurate song finder.
#
# WOW FACTOR:
# Reason: High wow factor!
#
# Overall: 8.9/9.0
#
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Group: Sreeja Rai, Nupur Bhalla, Tanvi Movva, and Abigail Albert
# - Period: CSP
#
# USAGE OF:
#
# - [X] Frontend
# - [X] Backend
# - [X] API
# - [] Agile
#
# HOOK:
# Points: 4.0
# Reason: Creative homepage displaying multiple fonts, colors, and good CSS styling.
#
# KNOWLEDGE:
# Points: 3.8
# Reason: Lots of API usage, discussed use of Grammar Bots API. Could've explained more in depth.
#
# VALUE:
# Points: 1.0
# Reason: Contains good study materials such as calculators and flashcards that work. Included the usage of AI.
#
# WOW FACTOR:
# Reason: Good wow factor, could've used more advanced coding concepts, but AI bot was impressive.
#
# Overall: 8.8/9.0
#
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Group: Hayden Chen, Tarun Jaikumar, Shuban Pal, and Deva Sasikumar
# - Period: CSP P1
#
# USAGE OF:
#
# - [X] Frontend
# - [X] Backend
# - [] API
# - [X] Agile
#
# HOOK:
# Points: 3.8
# Reason: Home page was the project, could've had a separate home page.
#
# KNOWLEDGE:
# Points: 3.9
# Reason: Used variety of code encryption, explained how code works. Did not disucss about the API.
#
# VALUE:
# Points: 1.0
# Reason: Code works perfectly accurately encrypts the code in any type you want.
#
# WOW FACTOR:
# Reason: High wow factor!
#
# Overall: 8.7/9.0
#
# --------------------------------------------------------------------------------------------------------------------------------
